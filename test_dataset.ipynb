# %%
from data import NoisyDataset

# %%
from torch.utils.data import DataLoader

# %%
data_ = NoisyDataset('train-jpg/', crop_size=128) # Default gaussian noise without clean targets

# %%
dl = DataLoader(data_, batch_size=1, shuffle=True)

# %%
import matplotlib.pyplot as plt

# %%
import torch
import numpy as np

# %%
def show(img):
    plt.figure()
    npimg = torch.squeeze(img).numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))

# %%
i = 0
for d in dl:
    plt.figure()
    show(d[0])
    show(d[-1])
    if i == 0:
        break

# %%
data_2 = NoisyDataset('dataset/train', train_noise_model=('text', 0.3)) # Text corruption without clean targets

# %%
dl2 = DataLoader(data_2, shuffle=True)

# %%
i = 0
for d in dl2:
    plt.figure()
    show(d[0])
    show(d[-1])
    if i == 0:
        break
# Out:
# corrupt target

# %%
data_3 = NoisyDataset('dataset/train', train_noise_model=('poisson', None), clean_targ=True)

# %%
dl3 = DataLoader(data_3, shuffle=True)

# %%
i = 0
for d in dl3:
    plt.figure()
    show(d[0])
    show(d[-1])
    if i == 0:
        break
# Out:
# int64
# [[[ 47  60  18]
#   [ 64  76  42]
#   [ 57  80  31]
#   ...
#   [ 25  55   4]
#   [ 62  95  40]
#   [ 66  79  19]]
#
#  [[ 54  77  33]
#   [ 74  91  41]
#   [ 46  74  23]
#   ...
#   [ 76  75  47]
#   [ 57  91  37]
#   [ 57  96  50]]
#
#  [[ 61  90  29]
#   [ 54  77  28]
#   [ 38  79  14]
#   ...
#   [ 24  69  21]
#   [ 39  62  31]
#   [ 67  93  31]]
#
#  ...
#
#  [[110 149  77]
#   [127 149  65]
#   [115 142  92]
#   ...
#   [ 98 147  64]
#   [133 139  67]
#   [124 143  93]]
#
#  [[110 137  62]
#   [ 87 115  44]
#   [137 145  76]
#   ...
#   [ 90 122  67]
#   [124 183  76]
#   [106 125  53]]
#
#  [[114 120  73]
#   [102 130  64]
#   [145 151  86]
#   ...
#   [102 130  93]
#   [125 152  90]
#   [ 88 103  61]]]

# %%
data_4 = NoisyDataset('dataset/train', train_noise_model=('multiplicative_bernoulli', 0.20), clean_targ=True)

# %%
dl_4 = DataLoader(data_4, shuffle=True)

# %%
i = 0
for d in dl_4:
    plt.figure()
    show(d[0])
    show(d[-1])
    if i == 0:
        break
