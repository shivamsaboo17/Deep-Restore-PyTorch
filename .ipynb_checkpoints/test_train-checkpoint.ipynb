# %%
from train_utils import Train

# %%
from model import SRResnet

# %%
architecture = SRResnet(3, 64)

# %%
params = {
    'noise_model': ('text', 0.3),
    'crop_size': 64,
    'clean_targs': False,
    'lr': 0.001,
    'epochs': 100,
    'bs': 2,
    'lossfn': 'l2',
    'cuda': True
}

# %%
trainer = Train(architecture, 'dataset/train', 'dataset/valid', params)

# %%
trainer.train()
# Out:
#  10%|▉         | 14/146 [00:37<05:56,  2.70s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3435b262f1ae> in <module>()
# ----> 1 trainer.train()
#
# /mnt/c/Users/shiva/Desktop/Noise2Noise-Pytorch/train_utils.py in train(self)
#      41                 source = _list[0]
#      42                 target = _list[-1]
# ---> 43                 _op = self.architecture(Variable(source))
#      44                 if len(_list) == 3:
#      45                     _loss = self.loss_fn(Variable(_list[1]) * _op, Variable(_list[1]) * Variable(target))
#
# ~/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /mnt/c/Users/shiva/Desktop/Noise2Noise-Pytorch/model.py in forward(self, input)
#      46     def forward(self, input):
#      47         _op1 = self.act(self.conv1(input))
# ---> 48         _op2 = self.conv2(self.resl(_op1))
#      49         op = self.conv3(torch.add(_op1, _op2))
#      50         return op
#
# ~/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# ~/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /mnt/c/Users/shiva/Desktop/Noise2Noise-Pytorch/model.py in forward(self, x)
#      27
#      28     def forward(self, x):
# ---> 29         return x + self.block2(self.block1(x))
#      30
#      31
#
# ~/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /mnt/c/Users/shiva/Desktop/Noise2Noise-Pytorch/model.py in forward(self, x)
#      15
#      16     def forward(self, x):
# ---> 17         op = self.bn(self.conv(x))
#      18         return self.act(op) if self.use_act else op
#      19
#
# ~/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     280     def forward(self, input):
#     281         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 282                         self.padding, self.dilation, self.groups)
#     283
#     284
#
# ~/.pyenv/versions/3.6.0/envs/general/lib/python3.6/site-packages/torch/nn/functional.py in conv2d(input, weight, bias, stride, padding, dilation, groups)
#      88                 _pair(0), groups, torch.backends.cudnn.benchmark,
#      89                 torch.backends.cudnn.deterministic, torch.backends.cudnn.enabled)
# ---> 90     return f(input, weight, bias)
#      91
#      92
#
# KeyboardInterrupt:

# %%
m = trainer.architecture

# %%
from data import NoisyDataset

# %%
from torch.utils.data import DataLoader

# %%
data_ = NoisyDataset('dataset/valid', crop_size=128, clean_targ=True, train_noise_model=('text', 0.3)) # Default gaussian noise without clean targets

# %%
dl = DataLoader(data_, batch_size=1, shuffle=True)

# %%
import matplotlib.pyplot as plt

# %%
import torch
import numpy as np
from torch.autograd import Variable

# %%
def show(img, a):
    plt.figure()
    if a == 'v':
        npimg = torch.squeeze(img).data.cpu().numpy()
    else:
        npimg = torch.squeeze(img).numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))

# %%
i = 0
for (source, target) in dl:
    plt.figure()
    pred = m(Variable(source.cuda()))
    show(pred, 'v')
    show(source, 't')
    show(target, 't')
    if i == 0:
        break
